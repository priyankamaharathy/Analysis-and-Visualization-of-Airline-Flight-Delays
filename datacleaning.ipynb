# %%
import pandas as pd

# %%
df = pd.read_csv(r'F:\Airline_Delay.csv')
df
# Out:
#         year  month carrier            carrier_name airport  arr_flights  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE         89.0
# 1       2023      8      9E       Endeavor Air Inc.     ABY         62.0
# 2       2023      8      9E       Endeavor Air Inc.     AEX         62.0
# 3       2023      8      9E       Endeavor Air Inc.     AGS         66.0
# 4       2023      8      9E       Endeavor Air Inc.     ALB         92.0
# ...      ...    ...     ...                     ...     ...          ...
# 171661  2013      8      YV      Mesa Airlines Inc.     TRI          7.0
# 171662  2013      8      YV      Mesa Airlines Inc.     YUM          2.0
# 171663  2013      8      YV      Mesa Airlines Inc.     SLC          2.0
# 171664  2013      8      DL    Delta Air Lines Inc.     SBN          1.0
# 171665  2013      8      F9  Frontier Airlines Inc.     MTJ          1.0
#
#         arr_del15  arr_cancelled  arr_delay  carrier_delay  \
# ...

# %%
df.drop_duplicates()
# Out:
#         year  month carrier            carrier_name airport  arr_flights  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE         89.0
# 1       2023      8      9E       Endeavor Air Inc.     ABY         62.0
# 2       2023      8      9E       Endeavor Air Inc.     AEX         62.0
# 3       2023      8      9E       Endeavor Air Inc.     AGS         66.0
# 4       2023      8      9E       Endeavor Air Inc.     ALB         92.0
# ...      ...    ...     ...                     ...     ...          ...
# 171661  2013      8      YV      Mesa Airlines Inc.     TRI          7.0
# 171662  2013      8      YV      Mesa Airlines Inc.     YUM          2.0
# 171663  2013      8      YV      Mesa Airlines Inc.     SLC          2.0
# 171664  2013      8      DL    Delta Air Lines Inc.     SBN          1.0
# 171665  2013      8      F9  Frontier Airlines Inc.     MTJ          1.0
#
#         arr_del15  arr_cancelled  arr_delay  carrier_delay  \
# ...

# %%
df = df[df['year'] != 2013]
print(df)
# Out:
#         year  month carrier              carrier_name airport  arr_flights  \
# 0       2023      8      9E         Endeavor Air Inc.     ABE         89.0
# 1       2023      8      9E         Endeavor Air Inc.     ABY         62.0
# 2       2023      8      9E         Endeavor Air Inc.     AEX         62.0
# 3       2023      8      9E         Endeavor Air Inc.     AGS         66.0
# 4       2023      8      9E         Endeavor Air Inc.     ALB         92.0
# ...      ...    ...     ...                       ...     ...          ...
# 164928  2014      1      WN    Southwest Airlines Co.     SJU        282.0
# 164929  2014      1      WN    Southwest Airlines Co.     SLC        889.0
# 164930  2014      1      WN    Southwest Airlines Co.     SMF       1813.0
# 164931  2014      1      WN    Southwest Airlines Co.     SNA       1367.0
# 164932  2014      1      EV  ExpressJet Airlines Inc.     MLB          2.0
#
#         arr_del15  arr_cancelled  arr_delay  carrier_delay  \
# ...

# %%
df = df[df['year'] != 2014]
print(df)
# Out:
#         year  month carrier            carrier_name airport  arr_flights  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE         89.0
# 1       2023      8      9E       Endeavor Air Inc.     ABY         62.0
# 2       2023      8      9E       Endeavor Air Inc.     AEX         62.0
# 3       2023      8      9E       Endeavor Air Inc.     AGS         66.0
# 4       2023      8      9E       Endeavor Air Inc.     ALB         92.0
# ...      ...    ...     ...                     ...     ...          ...
# 150948  2015      1      WN  Southwest Airlines Co.     ONT        892.0
# 150949  2015      1      WN  Southwest Airlines Co.     ORF        151.0
# 150950  2015      1      WN  Southwest Airlines Co.     PBI        251.0
# 150951  2015      1      WN  Southwest Airlines Co.     PDX        793.0
# 150952  2015      1      WN  Southwest Airlines Co.     PHL        773.0
#
#         arr_del15  arr_cancelled  arr_delay  carrier_delay  \
# ...

# %%
df = df[df['year'] != 2015]
print(df)
# Out:
#         year  month carrier            carrier_name airport  arr_flights  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE         89.0
# 1       2023      8      9E       Endeavor Air Inc.     ABY         62.0
# 2       2023      8      9E       Endeavor Air Inc.     AEX         62.0
# 3       2023      8      9E       Endeavor Air Inc.     AGS         66.0
# 4       2023      8      9E       Endeavor Air Inc.     ALB         92.0
# ...      ...    ...     ...                     ...     ...          ...
# 137420  2016      1      WN  Southwest Airlines Co.     BOI        291.0
# 137421  2016      1      WN  Southwest Airlines Co.     BOS        904.0
# 137422  2016      1      WN  Southwest Airlines Co.     BUF        511.0
# 137423  2016      1      OO   SkyWest Airlines Inc.     LAR         52.0
# 137424  2016      1      DL    Delta Air Lines Inc.     DLH          1.0
#
#         arr_del15  arr_cancelled  arr_delay  carrier_delay  \
# ...

# %%
df = df[df['year'] != 2016]
print(df)
# Out:
#         year  month carrier            carrier_name airport  arr_flights  \
# 0       2023      8      9E       Endeavor Air Inc.     ABE         89.0
# 1       2023      8      9E       Endeavor Air Inc.     ABY         62.0
# 2       2023      8      9E       Endeavor Air Inc.     AEX         62.0
# 3       2023      8      9E       Endeavor Air Inc.     AGS         66.0
# 4       2023      8      9E       Endeavor Air Inc.     ALB         92.0
# ...      ...    ...     ...                     ...     ...          ...
# 125203  2017      1      WN  Southwest Airlines Co.     SNA       1576.0
# 125204  2017      1      WN  Southwest Airlines Co.     STL       2914.0
# 125205  2017      1      WN  Southwest Airlines Co.     TPA       2390.0
# 125206  2017      1      WN  Southwest Airlines Co.     TUL        404.0
# 125207  2017      1      WN  Southwest Airlines Co.     TUS        372.0
#
#         arr_del15  arr_cancelled  arr_delay  carrier_delay  \
# ...

# %%
df = df[df['year'] != 2017]
print(df)
# Out:
#         year  month carrier       carrier_name airport  arr_flights  \
# 0       2023      8      9E  Endeavor Air Inc.     ABE         89.0
# 1       2023      8      9E  Endeavor Air Inc.     ABY         62.0
# 2       2023      8      9E  Endeavor Air Inc.     AEX         62.0
# 3       2023      8      9E  Endeavor Air Inc.     AGS         66.0
# 4       2023      8      9E  Endeavor Air Inc.     ALB         92.0
# ...      ...    ...     ...                ...     ...          ...
# 112685  2018      1      YX   Republic Airline     STL        258.0
# 112686  2018      1      YX   Republic Airline     SYR        114.0
# 112687  2018      1      YX   Republic Airline     TUL         67.0
# 112688  2018      1      YX   Republic Airline     TVC         25.0
# 112689  2018      1      YX   Republic Airline     XNA        140.0
#
#         arr_del15  arr_cancelled  arr_delay  carrier_delay  \
# 0            13.0            2.0     1375.0           71.0
# ...

# %%
df = df[df['year'] != 2018]
print(df)
# Out:
#        year  month carrier       carrier_name airport  arr_flights  arr_del15  \
# 0      2023      8      9E  Endeavor Air Inc.     ABE         89.0       13.0
# 1      2023      8      9E  Endeavor Air Inc.     ABY         62.0       10.0
# 2      2023      8      9E  Endeavor Air Inc.     AEX         62.0       10.0
# 3      2023      8      9E  Endeavor Air Inc.     AGS         66.0       12.0
# 4      2023      8      9E  Endeavor Air Inc.     ALB         92.0       22.0
# ...     ...    ...     ...                ...     ...          ...        ...
# 92472  2019      1      MQ          Envoy Air     RIC        195.0       68.0
# 92473  2019      1      MQ          Envoy Air     ROA         52.0       14.0
# 92474  2019      1      MQ          Envoy Air     ROC        106.0       26.0
# 92475  2019      1      MQ          Envoy Air     RST        116.0       35.0
# 92476  2019      1      MQ          Envoy Air     SAT         26.0        4.0
#
# ...

# %%
df = df[df['year'] != 2019]
print(df)
# Out:
#        year  month carrier       carrier_name airport  arr_flights  arr_del15  \
# 0      2023      8      9E  Endeavor Air Inc.     ABE         89.0       13.0
# 1      2023      8      9E  Endeavor Air Inc.     ABY         62.0       10.0
# 2      2023      8      9E  Endeavor Air Inc.     AEX         62.0       10.0
# 3      2023      8      9E  Endeavor Air Inc.     AGS         66.0       12.0
# 4      2023      8      9E  Endeavor Air Inc.     ALB         92.0       22.0
# ...     ...    ...     ...                ...     ...          ...        ...
# 71526  2020      1      YX   Republic Airline     TUS          7.0        0.0
# 71527  2020      1      YX   Republic Airline     TVC          1.0        0.0
# 71528  2020      1      YX   Republic Airline     TYS        112.0       10.0
# 71529  2020      1      YX   Republic Airline     VPS          8.0        1.0
# 71530  2020      1      YX   Republic Airline     XNA        246.0       28.0
#
# ...

# %%
df
# Out:
#        year  month carrier       carrier_name airport  arr_flights  arr_del15  \
# 0      2023      8      9E  Endeavor Air Inc.     ABE         89.0       13.0
# 1      2023      8      9E  Endeavor Air Inc.     ABY         62.0       10.0
# 2      2023      8      9E  Endeavor Air Inc.     AEX         62.0       10.0
# 3      2023      8      9E  Endeavor Air Inc.     AGS         66.0       12.0
# 4      2023      8      9E  Endeavor Air Inc.     ALB         92.0       22.0
# ...     ...    ...     ...                ...     ...          ...        ...
# 71526  2020      1      YX   Republic Airline     TUS          7.0        0.0
# 71527  2020      1      YX   Republic Airline     TVC          1.0        0.0
# 71528  2020      1      YX   Republic Airline     TYS        112.0       10.0
# 71529  2020      1      YX   Republic Airline     VPS          8.0        1.0
# 71530  2020      1      YX   Republic Airline     XNA        246.0       28.0
#
# ...
